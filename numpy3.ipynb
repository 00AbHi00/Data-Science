# %% [markdown]
# # 1. Importing a CSV and some functions

# %%
# Basic importing of csv, without csv...
import numpy as np
csvFile=np.loadtxt('csv1.csv',delimiter=',',dtype='str')
print(csvFile)
# Out:
# [['Sno' 'Year' 'Month' 'Category' 'Amount']
#  ['1' '2024' 'Jan' 'Food ' '100']
#  ['2' '2024' 'Feb' 'House' '200']
#  ['3' '2024' 'Jan' 'House' '30']
#  ['4' '2024' 'Feb' 'Food ' '30']
#  ['5' '2024' 'Mar' 'House' '1000']
#  ['6' '2024' 'Apr' 'Petrol' '20']
#  ['7' '2024' 'May' 'Petrol' '40']
#  ['7' '2024' 'May' 'Petrol' '500']
#  ['8' '2024' 'Jun' 'Food ' '600']
#  ['9' '2024' 'Jul' 'Food ' '70']
#  ['10' '2024' 'Aug' 'Food ' '100']
#  ['11' '2024' 'Sep' 'House' '50']
#  ['12' '2024' 'Oct' 'House' '100']
#  ['13' '2024' 'Nov' 'Food ' '200']
#  ['14' '2024' 'Dec' 'House' '250']
#  ['15' '2025' 'Jan' 'Petrol' '100']
#  ['16' '2025' 'Feb' 'Petrol' '500']
#  ['17' '2025' 'Mar' 'Petrol' '600']
#  ['18' '2025' 'Apr' 'Food ' '30']
#  ['19' '2025' 'May' 'Food ' '450']]

# %%
# Seperating headers and content
# Headers are contained in [0] 1st row so, we seperate the headers as such
print("Headers",csvFile[0, :])
# print("Conent",csvFile[1:,:])
header, content=csvFile[0,:], csvFile[1:,:]
# I was finding a better way for destructuring numpy array but looks like this is it

import matplotlib.pyplot as plt
# Printing top 3 rows
print(content[0:3])
# Out:
# Headers ['Sno' 'Year' 'Month' 'Category' 'Amount']
# [['1' '2024' 'Jan' 'Food ' '100']
#  ['2' '2024' 'Feb' 'House' '200']
#  ['3' '2024' 'Jan' 'House' '30']]
