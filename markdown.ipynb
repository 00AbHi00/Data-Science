# %% [markdown]
# <link rel="stylesheet" href="style.css">
# #### 1. Introduction to markdown
# <div class='title'> title </div>
# Markdown is a light markup language (like html) which is widely used in documentation (like github readme), Blogging, and note-taking, HTML itself can also be written inplace of writing markup, styling can aloso be done with inline css.
# {PRO TIP: \\ can be used for excaping characters (works same like other programs)}

# %% [markdown]
# ### 2. Writing headings
# <br/>
# <div class="title"> Title </div>
# <pre>
# &lt;h1> -> # &lt;/h1> {\n}
# &lt;h2 style="color:red"> -> ##  &lt;/h2>
# &lt;h3> -> ### &lt;/h3>
# ..
# ..
# &lt;h6> -> ###### &lt;/h6>
# </pre>

# %% [markdown]
# ### 3. Going to a next line:
# Simply entering to next line doesn't work, to make that work double space at the end of the line and enter is required.
# ehll
#
#
# <pre>
# HTML tag pre can also be used for pre-wrapping pre tag
# Hello
# My name
# is Abhishek SIlwal
# </pre>
# Pre can also be used for
# <pre> <code>```python def hello(): print("Hello, Markdown!") ``` </code></pre>
#
# or br/ tag can also be used

# %% [markdown]
# ### 4. Generating Tables
#
# Pipe operator (|) can be used with Dash(-) for effective control, please make sure that the table is valid.
# Table tag can also be used
#
# | Name    | Age | Country   |
# |---------|-----|-----------|
# |-----------------------------|
# | Alice   | 24  | USA       |----|
# | Bob     | 30  | Canada    |----|

# %% [markdown]
# ## 5. Creating Lists
# \-*+ can be used for creating lists
# + hello
# * Hi
# + Bye
# <br/>
# Check lists work in Github only and can be created as:
# <pre>
# - [x] Finished Task
# - [ ] Pending Task
# </pre>
# -[x] Finished Task
# -[ ] Pending Task

# %% [markdown]
# Nested Quotes can be used with \> \>>...
#
# > This is a quote.
# >> Nested quote

# %% [markdown]
# ### 6. Useful Stylings:
# <style>
#     .title{
#         color:red;
#     }
# </style>
# <pre>
# *Italic* or _Italic_
# **Bold** or __Bold__
# ***Bold Italic***
# ~~Strikethrough~~
# </pre>
# *Italic* or _Italic_
# **Bold** or __Bold__
# ***Bold Italic***
# ~~Strikethrough~~

# %% [markdown]
# 7. Links and Images can be shown as follows as follows
# <pre>
# [OpenAI](https://www.openai.com)
# [Image1](img1.jpg)
# </pre>
# [OpenAI](https://www.openai.com)
# [Image1](img1.jpg)

# %% [markdown]
# ## Styling in Markdown: USE CSS, almost all stylings i tried works
#
# <div class='title' style='display:flex; justify-content:center; background:rgba(0,0,2,0.3); padding:3px;' >
#     <div> This </div>
#     <div> is </div>
#     <div> LIT 🔥 </div>
#
# </div>
